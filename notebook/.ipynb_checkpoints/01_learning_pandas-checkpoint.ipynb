# %%
import pandas as pd

# %%
data = {
    "Driver": ["Hamilton", "Verstappen", "Leclerc", "Norris"],
    "Team": ["Mercedes", "Red Bull", "Ferrari", "McLaren"],
    "Wins": [105, 65, 8, 5]
}

df = pd.DataFrame(data)

df
# Out:
#        Driver      Team  Wins
# 0    Hamilton  Mercedes   105
# 1  Verstappen  Red Bull    65
# 2     Leclerc   Ferrari     8
# 3      Norris   McLaren     5

# %%
df["Driver"]
# Out:
# 0      Hamilton
# 1    Verstappen
# 2       Leclerc
# 3        Norris
# Name: Driver, dtype: object

# %%
df["Wins"]
# Out:
# 0    105
# 1     65
# 2      8
# 3      5
# Name: Wins, dtype: int64

# %%
df["Wins"].mean()
# Out:
# np.float64(45.75)

# %%
df["Wins"].max()
# Out:
# 105

# %%
df["Wins"].min()
# Out:
# 5

# %%
df[df["Wins"] > 10]
# Out:
#        Driver      Team  Wins
# 0    Hamilton  Mercedes   105
# 1  Verstappen  Red Bull    65
